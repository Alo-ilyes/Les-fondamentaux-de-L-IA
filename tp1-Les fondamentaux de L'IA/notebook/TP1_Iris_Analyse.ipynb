# %% [markdown]
# # TP1 — Analyse d’un algorithme en fonctionnement
# Notebook minimal fourni avec le repo. Le code principal est dans `src/tp1_iris.py`.

# %%
# !pip install -r ../requirements.txt

# %%
# %run ../src/tp1_iris.py
